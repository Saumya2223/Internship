# %% [markdown]
# # Zomato Restaurant

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('C:/Users/jdjra/OneDrive/Desktop/Internship/evaluation projects/3rd phase/zomato.csv')

# %%
df2=pd.read_csv('C:/Users/jdjra/OneDrive/Desktop/Internship/evaluation projects/3rd phase/Country-Code.csv')

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208           stanbul
# 9547        5908749              Ceviz A  ac۱           208           stanbul
# 9548        5915807                     Huqqa           208           stanbul
# 9549        5916112               A   k Kahve           208           stanbul
# 9550        5927402  Walter's Coffee Roastery           208           stanbul
#
# ...

# %%
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df=pd.merge(df1,df2)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208           stanbul
# 9547        5908749              Ceviz A  ac۱           208           stanbul
# 9548        5915807                     Huqqa           208           stanbul
# 9549        5916112               A   k Kahve           208           stanbul
# 9550        5927402  Walter's Coffee Roastery           208           stanbul
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df.dropna(subset=['Cuisines'],inplace=True)

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %%
df['Restaurant ID'].value_counts()
# Out:
# 6317637     1
# 18336474    1
# 18382047    1
# 18441566    1
# 18441669    1
#            ..
# 18451576    1
# 580         1
# 308703      1
# 60          1
# 5927402     1
# Name: Restaurant ID, Length: 9542, dtype: int64

# %%
df['Restaurant Name'].value_counts()
# Out:
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# The Town House Cafe          1
# The G.T. Road                1
# The Darzi Bar & Kitchen      1
# Smoke On Water               1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7437, dtype: int64

# %%
df['Country Code'].value_counts()
# Out:
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %%
df['Locality Verbose'].value_counts()
# Out:
# Connaught Place, New Delhi                    122
# Rajouri Garden, New Delhi                      99
# Shahdara, New Delhi                            87
# Defence Colony, New Delhi                      86
# Pitampura, New Delhi                           85
#                                              ...
# Ramada Gurgaon Central, Sector 44, Gurgaon      1
# Sector 5, Gurgaon                               1
# Sector 53, Gurgaon                              1
# The Claremont, MG Road, Gurgaon                 1
# Moda,   stanbul                                 1
# Name: Locality Verbose, Length: 1263, dtype: int64

# %%
df['Locality'].value_counts()
# Out:
# Connaught Place                                122
# Rajouri Garden                                  99
# Shahdara                                        87
# Defence Colony                                  86
# Pitampura                                       85
#                                               ...
# Omaxe Celebration Mall, Sohna Road, Gurgaon      1
# Park Inn, Sector 15, Gurgaon                     1
# Plaza Mall, MG Road                              1
# Ramada Gurgaon Central, Sector 44                1
# Moda                                             1
# Name: Locality, Length: 1206, dtype: int64

# %%
df['Address'].value_counts()
# Out:
# Dilli Haat, INA, New Delhi                                                   11
# Sector 41, Noida                                                             11
# Greater Kailash (GK) 1, New Delhi                                            10
# The Imperial, Janpath, New Delhi                                              9
# Cyber Hub, DLF Cyber City, Gurgaon                                            8
#                                                                              ..
# 108 & 126, Flyover Market, Defence Colony, New Delhi                          1
# Shop 25,27 & 29, Defence Colony Flyover Market, Defence Colony, New Delhi     1
# D  Block, Defence Colony, New Delhi                                           1
# A-1, Defence Colony, New Delhi                                                1
# Cafea  a Mahallesi, Bademalt۱ Sokak, No 21/B, Kad۱k _y,   stanbul             1
# Name: Address, Length: 8910, dtype: int64

# %%
df['Cuisines'].value_counts()
# Out:
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
remove_col=['Restaurant ID',
            'Country Code',
            'Locality Verbose',
            'Address',
           ]

for i in remove_col:
    df=df.drop([i],axis=1)

# %%
df
# Out:
#                Restaurant Name              City  \
# 0             Le Petit Souffle       Makati City
# 1             Izakaya Kikufuji       Makati City
# 2       Heat - Edsa Shangri-La  Mandaluyong City
# 3                         Ooma  Mandaluyong City
# 4                  Sambo Kojin  Mandaluyong City
# ...                        ...               ...
# 9546               Naml۱ Gurme           stanbul
# 9547              Ceviz A  ac۱           stanbul
# 9548                     Huqqa           stanbul
# 9549               A   k Kahve           stanbul
# 9550  Walter's Coffee Roastery           stanbul
#
#                                         Locality   Longitude   Latitude  \
# 0      Century City Mall, Poblacion, Makati City  121.027535  14.565443
# 1     Little Tokyo, Legaspi Village, Makati City  121.014101  14.553708
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City  121.056831  14.581404
# 3         SM Megamall, Ortigas, Mandaluyong City  121.056475  14.585318
# ...

# %%
df
# Out:
#                Restaurant Name              City  \
# 0             Le Petit Souffle       Makati City
# 1             Izakaya Kikufuji       Makati City
# 2       Heat - Edsa Shangri-La  Mandaluyong City
# 3                         Ooma  Mandaluyong City
# 4                  Sambo Kojin  Mandaluyong City
# ...                        ...               ...
# 9546               Naml۱ Gurme           stanbul
# 9547              Ceviz A  ac۱           stanbul
# 9548                     Huqqa           stanbul
# 9549               A   k Kahve           stanbul
# 9550  Walter's Coffee Roastery           stanbul
#
#                                         Locality   Longitude   Latitude  \
# 0      Century City Mall, Poblacion, Makati City  121.027535  14.565443
# 1     Little Tokyo, Legaspi Village, Makati City  121.014101  14.553708
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City  121.056831  14.581404
# 3         SM Megamall, Ortigas, Mandaluyong City  121.056475  14.585318
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9542 non-null   object
#  1   City                  9542 non-null   object
#  2   Locality              9542 non-null   object
#  3   Longitude             9542 non-null   float64
#  4   Latitude              9542 non-null   float64
#  5   Cuisines              9542 non-null   object
#  6   Average Cost for two  9542 non-null   int64
#  7   Currency              9542 non-null   object
#  8   Has Table booking     9542 non-null   object
#  9   Has Online delivery   9542 non-null   object
#  10  Is delivering now     9542 non-null   object
#  11  Switch to order menu  9542 non-null   object
#  12  Price range           9542 non-null   int64
#  13  Aggregate rating      9542 non-null   float64
#  14  Rating color          9542 non-null   object
# ...

# %%
catcols=[]
numcols=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        catcols.append(i)
    else:
        numcols.append(i)

# %%
catcols
# Out:
# ['Restaurant Name',
#  'City',
#  'Locality',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text',
#  'Country']

# %%
numcols
# Out:
# ['Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
for i in catcols[4:]:
    plt.figure(figsize=(21,5))
    sns.histplot(df[i],color='green')
    plt.show()

# %%
for i in numcols:
  plt.figure(figsize=(21,5))
  sns.distplot(df[i],color='red')
  plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
for i in catcols:
    df[i]=label.fit_transform(df[i])

# %%
df
# Out:
#       Restaurant Name  City  Locality   Longitude   Latitude  Cuisines  \
# 0                3744    74       175  121.027535  14.565443       920
# 1                3169    74       596  121.014101  14.553708      1111
# 2                2895    76       312  121.056831  14.581404      1671
# 3                4701    76       864  121.056475  14.585318      1126
# 4                5516    76       864  121.057508  14.584450      1122
# ...               ...   ...       ...         ...        ...       ...
# 9546             4437     0       521   28.977392  41.022793      1813
# 9547             1313     0       546   29.041297  41.009847      1824
# 9548             3066     0       558   29.034640  41.055817      1110
# 9549               87     0       558   29.036019  41.057979      1657
# 9550             7232     0       672   29.026016  40.984776       331
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# ...

# %%
x1=df.drop(['Price range'],axis=1)
y1=df['Price range']

# %%
x1
# Out:
#       Restaurant Name  City  Locality   Longitude   Latitude  Cuisines  \
# 0                3744    74       175  121.027535  14.565443       920
# 1                3169    74       596  121.014101  14.553708      1111
# 2                2895    76       312  121.056831  14.581404      1671
# 3                4701    76       864  121.056475  14.585318      1126
# 4                5516    76       864  121.057508  14.584450      1122
# ...               ...   ...       ...         ...        ...       ...
# 9546             4437     0       521   28.977392  41.022793      1813
# 9547             1313     0       546   29.041297  41.009847      1824
# 9548             3066     0       558   29.034640  41.055817      1110
# 9549               87     0       558   29.036019  41.057979      1657
# 9550             7232     0       672   29.026016  40.984776       331
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# ...

# %%
y1.value_counts()
# Out:
# 1    4438
# 2    3113
# 3    1405
# 4     586
# Name: Price range, dtype: int64

# %%
x2=df.drop(['Average Cost for two'],axis=1)

# %%
y2=df['Average Cost for two']

# %%
x2
# Out:
#       Restaurant Name  City  Locality   Longitude   Latitude  Cuisines  \
# 0                3744    74       175  121.027535  14.565443       920
# 1                3169    74       596  121.014101  14.553708      1111
# 2                2895    76       312  121.056831  14.581404      1671
# 3                4701    76       864  121.056475  14.585318      1126
# 4                5516    76       864  121.057508  14.584450      1122
# ...               ...   ...       ...         ...        ...       ...
# 9546             4437     0       521   28.977392  41.022793      1813
# 9547             1313     0       546   29.041297  41.009847      1824
# 9548             3066     0       558   29.034640  41.055817      1110
# 9549               87     0       558   29.036019  41.057979      1657
# 9550             7232     0       672   29.026016  40.984776       331
#
#       Currency  Has Table booking  Has Online delivery  Is delivering now  \
# ...

# %%
y2
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9542, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_1=scaler.fit_transform(x1)
x1=pd.DataFrame(x_1,columns=x1.columns)
x1
# Out:
#       Restaurant Name      City  Locality  Longitude  Latitude  Cuisines  \
# 0            0.044404 -0.190776 -1.541227   1.377641 -1.024849 -0.134486
# 1           -0.224298 -0.190776 -0.204508   1.377315 -1.025915  0.236894
# 2           -0.352340 -0.103232 -1.106237   1.378352 -1.023399  1.325756
# 3            0.491618 -0.103232  0.646420   1.378344 -1.023043  0.266060
# 4            0.872474 -0.103232  0.646420   1.378369 -1.023122  0.258282
# ...               ...       ...       ...        ...       ...       ...
# 9537         0.368249 -3.429887 -0.442641  -0.856833  1.378286  1.601860
# 9538        -1.091622 -3.429887 -0.363263  -0.855281  1.377110  1.623248
# 9539        -0.272431 -3.429887 -0.325162  -0.855443  1.381285  0.234950
# 9540        -1.664542 -3.429887 -0.325162  -0.855410  1.381482  1.298534
# 9541         1.674375 -3.429887  0.036800  -0.855652  1.374833 -1.279735
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# ...

# %%
x_2=scaler.fit_transform(x2)
x2=pd.DataFrame(x_2,columns=x2.columns)
x2
# Out:
#       Restaurant Name      City  Locality  Longitude  Latitude  Cuisines  \
# 0            0.044404 -0.190776 -1.541227   1.377641 -1.024849 -0.134486
# 1           -0.224298 -0.190776 -0.204508   1.377315 -1.025915  0.236894
# 2           -0.352340 -0.103232 -1.106237   1.378352 -1.023399  1.325756
# 3            0.491618 -0.103232  0.646420   1.378344 -1.023043  0.266060
# 4            0.872474 -0.103232  0.646420   1.378369 -1.023122  0.258282
# ...               ...       ...       ...        ...       ...       ...
# 9537         0.368249 -3.429887 -0.442641  -0.856833  1.378286  1.601860
# 9538        -1.091622 -3.429887 -0.363263  -0.855281  1.377110  1.623248
# 9539        -0.272431 -3.429887 -0.325162  -0.855443  1.381285  0.234950
# 9540        -1.664542 -3.429887 -0.325162  -0.855410  1.381482  1.298534
# 9541         1.674375 -3.429887  0.036800  -0.855652  1.374833 -1.279735
#
#       Currency  Has Table booking  Has Online delivery  Is delivering now  \
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Values'] = [variance_inflation_factor(x1.values, i) for i in range(len(x1.columns))]
vif['Features'] = x1.columns
print(vif)
# Out:
#       Values              Features
# 0   1.006795       Restaurant Name
# 1   1.103565                  City
# 2   1.053436              Locality
# 3   3.406062             Longitude
# 4   1.316810              Latitude
# 5   1.043153              Cuisines
# 6   1.029406  Average Cost for two
# 7   1.314513              Currency
# 8   1.098694     Has Table booking
# 9   1.159269   Has Online delivery
# 10  1.012341     Is delivering now
# 11       NaN  Switch to order menu
# 12  1.630206      Aggregate rating
# 13  1.230391          Rating color
# 14  1.313434           Rating text
# 15  1.236411                 Votes
# 16  3.546879               Country

# %%
x2=x2.drop(['Switch to order menu'],axis=1)

# %%
x1=x1.drop(['Switch to order menu'],axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Values'] = [variance_inflation_factor(x1.values, i) for i in range(len(x1.columns))]
vif['Features'] = x1.columns
print(vif)
# Out:
#       Values              Features
# 0   1.006795       Restaurant Name
# 1   1.103565                  City
# 2   1.053436              Locality
# 3   3.406062             Longitude
# 4   1.316810              Latitude
# 5   1.043153              Cuisines
# 6   1.029406  Average Cost for two
# 7   1.314513              Currency
# 8   1.098694     Has Table booking
# 9   1.159269   Has Online delivery
# 10  1.012341     Is delivering now
# 11  1.630206      Aggregate rating
# 12  1.230391          Rating color
# 13  1.313434           Rating text
# 14  1.236411                 Votes
# 15  3.546879               Country

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Values'] = [variance_inflation_factor(x2.values, i) for i in range(len(x2.columns))]
vif['Features'] = x2.columns
print(vif)
# Out:
#       Values             Features
# 0   1.007953      Restaurant Name
# 1   1.104078                 City
# 2   1.053496             Locality
# 3   3.392996            Longitude
# 4   1.381470             Latitude
# 5   1.044780             Cuisines
# 6   1.317727             Currency
# 7   1.456578    Has Table booking
# 8   1.158732  Has Online delivery
# 9   1.013111    Is delivering now
# 10  1.898666          Price range
# 11  1.820688     Aggregate rating
# 12  1.230562         Rating color
# 13  1.345880          Rating text
# 14  1.247464                Votes
# 15  3.605080              Country

# %%
#importing models and libraries
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
maxAccu=0
maxRS=0

for i in range(1,100):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
    rfr=RandomForestClassifier()
    rfr.fit(x1_train, y1_train)
    pred=rfr.predict(x1_test)
    acc=accuracy_score(y1_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs = i
print('Best acc is ', maxAccu, 'at random state', maxRs)
# Out:
# Best acc is  0.9793922458959133 at random state 46

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
def model(m):
    m.fit(x1_train,y1_train)
    predt=m.predict(x1_train)
    pred=m.predict(x1_test)
    print('Training Accuracy Score: ',accuracy_score(y1_train,predt)*100)
    print('Accuracy Score: ',accuracy_score(y1_test,pred)*100)
    print(confusion_matrix(y1_test,pred))
    print(classification_report(y1_test,pred))

# %%
rfc=RandomForestClassifier()
model(rfc)
# Out:
# Training Accuracy Score:  100.0
# Accuracy Score:  96.78658749563395
# [[1317    5    1    0]
#  [  10  919   15    0]
#  [   0   28  392    8]
#  [   0    0   25  143]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1323
#            2       0.97      0.97      0.97       944
#            3       0.91      0.92      0.91       428
#            4       0.95      0.85      0.90       168
#
#     accuracy                           0.97      2863
#    macro avg       0.95      0.93      0.94      2863
# weighted avg       0.97      0.97      0.97      2863

# %%
lr=LogisticRegression()
model(lr)
# Out:
# Training Accuracy Score:  64.41083994609971
# Accuracy Score:  62.8361858190709
# [[1105  203   15    0]
#  [ 416  448   76    4]
#  [  38  155  226    9]
#  [  18   37   93   20]]
#               precision    recall  f1-score   support
#
#            1       0.70      0.84      0.76      1323
#            2       0.53      0.47      0.50       944
#            3       0.55      0.53      0.54       428
#            4       0.61      0.12      0.20       168
#
#     accuracy                           0.63      2863
#    macro avg       0.60      0.49      0.50      2863
# weighted avg       0.62      0.63      0.61      2863

# %%
svc=SVC()
model(svc)
# Out:
# Training Accuracy Score:  66.50696212007784
# Accuracy Score:  62.521830247991616
# [[1073  232   18    0]
#  [ 426  415  100    3]
#  [  50  103  260   15]
#  [  12   16   98   42]]
#               precision    recall  f1-score   support
#
#            1       0.69      0.81      0.74      1323
#            2       0.54      0.44      0.49       944
#            3       0.55      0.61      0.58       428
#            4       0.70      0.25      0.37       168
#
#     accuracy                           0.63      2863
#    macro avg       0.62      0.53      0.54      2863
# weighted avg       0.62      0.63      0.61      2863

# %%
gb=GradientBoostingClassifier()
model(gb)
# Out:
# Training Accuracy Score:  99.31127414283576
# Accuracy Score:  97.7645826056584
# [[1320    3    0    0]
#  [   7  929    7    1]
#  [   0   20  394   14]
#  [   0    0   12  156]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1323
#            2       0.98      0.98      0.98       944
#            3       0.95      0.92      0.94       428
#            4       0.91      0.93      0.92       168
#
#     accuracy                           0.98      2863
#    macro avg       0.96      0.96      0.96      2863
# weighted avg       0.98      0.98      0.98      2863

# %%
abc=AdaBoostClassifier()
model(abc)
# Out:
# Training Accuracy Score:  81.88351549633178
# Accuracy Score:  81.62766329025499
# [[1253   70    0    0]
#  [  14  923    7    0]
#  [   3  358   46   21]
#  [   0   39   14  115]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.95      0.97      1323
#            2       0.66      0.98      0.79       944
#            3       0.69      0.11      0.19       428
#            4       0.85      0.68      0.76       168
#
#     accuracy                           0.82      2863
#    macro avg       0.80      0.68      0.67      2863
# weighted avg       0.83      0.82      0.78      2863

# %%
bc=BaggingClassifier()
model(bc)
# Out:
# Training Accuracy Score:  99.86524928881569
# Accuracy Score:  98.14879497031086
# [[1319    4    0    0]
#  [   6  929    7    2]
#  [   0   10  409    9]
#  [   0    0   15  153]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1323
#            2       0.99      0.98      0.98       944
#            3       0.95      0.96      0.95       428
#            4       0.93      0.91      0.92       168
#
#     accuracy                           0.98      2863
#    macro avg       0.97      0.96      0.96      2863
# weighted avg       0.98      0.98      0.98      2863

# %%
etc=ExtraTreesClassifier()
model(etc)
# Out:
# Training Accuracy Score:  100.0
# Accuracy Score:  93.64303178484109
# [[1297   21    4    1]
#  [  16  896   31    1]
#  [   1   42  361   24]
#  [   0    4   37  127]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.98      0.98      1323
#            2       0.93      0.95      0.94       944
#            3       0.83      0.84      0.84       428
#            4       0.83      0.76      0.79       168
#
#     accuracy                           0.94      2863
#    macro avg       0.90      0.88      0.89      2863
# weighted avg       0.94      0.94      0.94      2863

# %%
from sklearn.model_selection import cross_val_score

# %%
def scr(m):
    score=cross_val_score(m,x1,y1)
    print(score)
    print(score.mean())
    print('Diff b/w Accuracy score & CV score: ',(accuracy_score(y1_test,pred) - score.mean())*100)

# %%
scr(rfc)
# Out:
# [0.4772132  0.96280775 0.99371069 0.99842767 0.85691824]
# 0.8578155114304634
# Diff b/w Accuracy score & CV score:  11.563890701173008

# %%
scr(lr)
# Out:
# [0.44002095 0.63488738 0.68920335 0.66247379 0.59119497]
# 0.6035560892736931
# Diff b/w Accuracy score & CV score:  36.98983291685004

# %%
scr(svc)
# Out:
# [0.2750131  0.52173913 0.64570231 0.64360587 0.61006289]
# 0.539224659095776
# Diff b/w Accuracy score & CV score:  43.42297593464175

# %%
scr(gb)
# Out:
# [0.3996857  0.96123625 0.9942348  0.99947589 0.83333333]
# 0.837593194764291
# Diff b/w Accuracy score & CV score:  13.586122367790255

# %%
scr(abc)
# Out:
# [0.68360398 0.82556312 0.92819706 0.9360587  0.77148847]
# 0.8289822675992458
# Diff b/w Accuracy score & CV score:  14.447215084294774

# %%
scr(bc)
# Out:
# [0.40806705 0.96385542 0.99475891 0.99842767 0.83018868]
# 0.8390595469106396
# Diff b/w Accuracy score & CV score:  13.439487153155394

# %%
scr(etc)
# Out:
# [0.39339969 0.83499214 0.94025157 0.95545073 0.86215933]
# 0.7972506926804841
# Diff b/w Accuracy score & CV score:  17.62037257617094

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Random Forest Classifier (RFC) might be overfitting the training data.
# 2. Logistic Regression (LR) is not fitting the data well, as both the training and test accuracy scores are relatively low.
# 3. Support Vector Classifier (SVC) model performance is suboptimal.
# 4. Gradient Boosting Classifier (GBC)model if also overfitting.
# 5. AdaBoost Classifier (ABC) is performing well on training and test data, its CV score mean is also satisfactory.
# 6. Bagging Classifier (BC), Extra Trees Classifier (ETC) are also overfitting.
#
# Hence, AdaBoost Classifier is our best performing model!

# %%
#importing RandomizedseachCV for hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    'n_estimators': [50, 100],
    'learning_rate':[1.0,0.0,0.5],
    'algorithm':['SAMME','SAMME.R'],
    'random_state': [10, None]
}

# %%
gsv = GridSearchCV(AdaBoostClassifier(), parameters)
gsv.fit(x1_train, y1_train)
print(gsv.best_params_)
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 1.0, 'n_estimators': 100, 'random_state': 10}

# %%
Hyper_abc=AdaBoostClassifier(algorithm='SAMME',learning_rate=1.0,n_estimators=100,random_state=10)

# %%
model(Hyper_abc)
# Out:
# Training Accuracy Score:  95.02919598742326
# Accuracy Score:  94.9703108627314
# [[1313    8    0    0]
#  [  21  906    8    2]
#  [   6   32  370   17]
#  [  10    0   40  130]]
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98      1321
#            2       0.96      0.97      0.96       937
#            3       0.89      0.87      0.88       425
#            4       0.87      0.72      0.79       180
#
#     accuracy                           0.95      2863
#    macro avg       0.92      0.89      0.90      2863
# weighted avg       0.95      0.95      0.95      2863

# %%
Final_model=Hyper_abc

# %%
#Saving our model
import joblib
joblib.dump(Final_model,'Zomato Price Range Prediction.pkl')
# Out:
# ['Zomato Price Range Prediction.pkl']

# %%
model=joblib.load('Zomato Price Range Prediction.pkl')
Prediction=model.predict(x1_test)
Prediction
# Out:
# array([1, 2, 1, ..., 2, 2, 2], dtype=int64)

# %%
Comparison=pd.DataFrame()
Comparison['True Value']=y1_test
Comparison['Prediciton']=Prediction
Comparison
# Out:
#       True Value  Prediciton
# 5854           1           1
# 8819           2           2
# 6867           1           1
# 6209           2           2
# 172            1           1
# ...          ...         ...
# 9515           3           4
# 6702           3           3
# 2750           2           2
# 6970           2           2
# 7022           2           2
#
# [2863 rows x 2 columns]

# %%
#importing libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#importing models
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR

# %%
maxAccu=0
maxRs=0
for i in range(1,200):
    x2_train,x2_test,y2_train,y2_test=train_test_split(x2,y2,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x2_train,y2_train)
    pred=lr.predict(x2_test)
    acc=r2_score(y2_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs = i
print(maxAccu, maxRs)
# Out:
# 0.07006953557038575 106

# %%
def model(m):
    m.fit(x2_train,y2_train)
    pred=m.predict(x2_test)
    print('R2 Score: ',r2_score(y2_test,pred)*100)
    print('R2 Score on training data: ',r2_score(y2_train,m.predict(x2_train))*100)
    print('MAE: ',mean_absolute_error(y2_test,pred))
    print('MSE: ',mean_squared_error(y2_test,pred))
    print('RMSE: ',np.sqrt(mean_squared_error(y2_test,pred)))
    sns.regplot(x=pred,y=y2_test)

# %%
lr=LinearRegression()
model(lr)
# Out:
# R2 Score:  1.7939842680907314
# R2 Score on training data:  3.310793474212026
# MAE:  1848.6315831967188
# MSE:  351778739.2403991
# RMSE:  18755.765493319625

# %%
rfr=RandomForestRegressor()
model(rfr)
# Out:
# R2 Score:  51.43060661438636
# R2 Score on training data:  94.57213082465546
# MAE:  540.5374017810373
# MSE:  173977936.51973435
# RMSE:  13190.06961769855

# %%
adr=AdaBoostRegressor()
model(adr)
# Out:
# R2 Score:  43.562984763591764
# R2 Score on training data:  88.41304979990109
# MAE:  829.6720791294931
# MSE:  202160141.80385998
# RMSE:  14218.303056407962

# %%
gbr=GradientBoostingRegressor()
model(gbr)
# Out:
# R2 Score:  44.54557454636324
# R2 Score on training data:  99.92667114952496
# MAE:  661.8751176249635
# MSE:  198640457.26724827
# RMSE:  14093.986564036744

# %%
dtr=DecisionTreeRegressor()
model(dtr)
# Out:
# R2 Score:  61.006243840115594
# R2 Score on training data:  100.0
# MAE:  498.8973284442116
# MSE:  139677536.838659
# RMSE:  11818.525154970013

# %%
model(KNN())
# Out:
# R2 Score:  41.348139719973645
# R2 Score on training data:  67.5659320432201
# MAE:  601.6630696699843
# MSE:  210093824.7992457
# RMSE:  14494.61364780882

# %%
model(Lasso())
# Out:
# R2 Score:  1.7940973172696606
# R2 Score on training data:  3.310780726517293
# MAE:  1846.9889252278197
# MSE:  351778334.2927252
# RMSE:  18755.754698031353

# %%
model(Ridge())
# Out:
# R2 Score:  1.7939826070915932
# R2 Score on training data:  3.3107929293116456
# MAE:  1848.5834007526412
# MSE:  351778745.19017905
# RMSE:  18755.765651931648

# %%
model(SVR())
# Out:
# R2 Score:  -0.06381882088442037
# R2 Score on training data:  -0.13098540661862224
# MAE:  828.5407309708527
# MSE:  358433480.5362956
# RMSE:  18932.339542071804

# %% [markdown]
# # Decision Tree Regressor is our best model!

# %% [markdown]
# Hyperparameter tuning

# %%
#importing RandomizedseachCV for hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {'criterion': ['squared_error', 'absolute_error'],
    'splitter':['best','random'],
    'max_depth':[None,1],
    'min_samples_split':[2,4],
    'min_samples_leaf':[0,2],
    'max_features':['auto','sqrt','log2'],
    'random_state':[106,None],
    'ccp_alpha': [0.0, 0.01, 0.001],
  
}

# %%
rsv = RandomizedSearchCV(DecisionTreeRegressor(),parameters,n_iter=10, n_jobs=-1)
rsv.fit(x2_train, y2_train)
print(rsv.best_params_)
# Out:
# {'splitter': 'best', 'random_state': 106, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0.0}

# %%
Hyper_dtr=DecisionTreeRegressor(splitter='best',random_state=106,min_samples_split=2,min_samples_leaf=2,max_features='auto',max_depth=None,criterion='squared_error',ccp_alpha=0.0)

# %%
model(Hyper_dtr)
# Out:
# R2 Score:  41.57798854778913
# R2 Score on training data:  95.86038530635506
# MAE:  612.3865025318665
# MSE:  209270495.08505034
# RMSE:  14466.184537916359

# %% [markdown]
# # Decision Tree Regressor accuracy after Hypertuning 41.57%.

# %%
Final_model=Hyper_dtr

# %%
#Saving our model
import joblib
joblib.dump(Final_model,'Zomato Average price.pkl')
# Out:
# ['Zomato Average price.pkl']

# %%
model=joblib.load('Zomato Average price.pkl')
Prediction=model.predict(x2_test)
Prediction
# Out:
# array([ 200.        ,  666.66666667,  300.        , ..., 1366.66666667,
#        1533.33333333,  400.        ])

# %%
Comparison=pd.DataFrame()
Comparison['True Value']=y2_test
Comparison['Prediciton']=Prediction
Comparison
# Out:
#       True Value   Prediciton
# 5854         300   200.000000
# 8819         650   666.666667
# 6867         150   300.000000
# 6209         700   775.000000
# 172           10    10.000000
# ...          ...          ...
# 6882         400   300.000000
# 5162        1000  1000.000000
# 1316        1000  1366.666667
# 2771        1200  1533.333333
# 2791         250   400.000000
#
# [1909 rows x 2 columns]
